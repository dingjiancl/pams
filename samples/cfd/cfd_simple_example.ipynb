# %%
from cfd_simple_agents import CFDSimpleAgent, CFDSimpleMarketMakerAgent
from cfd_market import CFDMarket, CFDSimulator
from pams.runners import SequentialRunner
from pams.logs.market_step_loggers import MarketStepSaver
import random

saver = MarketStepSaver()
runner = SequentialRunner(
    settings="./simple_config.json",
    prng=random.Random(42),
    logger=saver,
    simulator_class=CFDSimulator
)
runner.class_register(CFDSimpleAgent)
runner.class_register(CFDSimpleMarketMakerAgent)
runner.class_register(CFDMarket)
runner.main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/sf/18l7lmts0vsgny2k2v0gd_xh0000gn/T/ipykernel_63015/886044732.py in <module>
#      15 runner.class_register(CFDSimpleMarketMakerAgent)
#      16 runner.class_register(CFDMarket)
# ---> 17 runner.main()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pams/runners/base.py in main(self)
#      67         """main process. The process is executed while measuring time."""
#      68         setup_start_time_ns = time.time_ns()
# ---> 69         self._setup()
#      70         start_time_ns = time.time_ns()
#      71         self._run()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pams/runners/sequential.py in _setup(self)
#     390         self._generate_sessions()
#     391
# --> 392         _ = [func(**kwargs) for func, kwargs in self._pending_setups]
#     393
#     394     def _collect_orders_from_normal_agents(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pams/runners/sequential.py in <listcomp>(.0)
#     390         self._generate_sessions()
#     391
# --> 392         _ = [func(**kwargs) for func, kwargs in self._pending_setups]
#     393
#     394     def _collect_orders_from_normal_agents(
#
# ~/VS code project/cfd_forked/cfd/cfd/cfd_simple_agents.py in setup(self, settings, accessible_markets_ids, *args, **kwargs)
#      80         )
#      81         if "bid_ask_spread" not in settings:
# ---> 82             raise ValueError("bid_ask_spread is required for CFDSimpleMarketMakerAgent")
#      83         self.bid_ask_spread: float = settings["bid_ask_spread"]
#      84         self.positions: List[Dict[str, Any]] = []
#
# ValueError: bid_ask_spread is required for CFDSimpleMarketMakerAgent

# %%
import matplotlib.pyplot as plt
price_list = []
for log_dic in saver.market_step_logs:
    if log_dic["market_id"] == 3:
        price_list.append(log_dic["market_price"])
plt.plot(price_list)
plt.xlabel("ticks")
plt.ylabel("market price")
plt.show()
